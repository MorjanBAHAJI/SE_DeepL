# %% [markdown]
# ## ATTENTION DE N'EXECUTER OS.CHDIR QU'UNE SEULE FOIS, SINON ON SE RETROUVE DANS LE MAUVAIS DOSSIER, RELANCER LE KERNEL SINON

# %%
import os
os.chdir('..')
from utils.train_and_test import get_batch, plot_spectro
from utils.path import path_n_to_any
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## ATTENTION DE N'EXECUTER OS.CHDIR QU'UNE SEULE FOIS, SINON ON SE RETROUVE DANS LE MAUVAIS DOSSIER, RELANCER LE KERNEL SINON

# %% [markdown]
# # Plot Waveform with unet and ori

# %%
from utils.train_and_test import test, display_results, get_batch, plot_waveform
from utils.path import path_n_to_any
import matplotlib.pyplot as plt


SNR_= '-6dB' #Choisir son snr (il faut au préalable avoir bruité les sons pour des SNR donné avec gen_noise.py)
SNR_load = '-8dB' #le modèle qu'on souhaite charger (par défaut -8dB car c'est le plus aboutit)
num = 2 #Nombre de wavform à afficher

masktype=None # Type de masque ('Soft' ou 'Binary', ou None si on choisi la méthode unet)
output = 'ori' # Type de sortie ("mask" ou "ori")
model = 'unet' # modèle choisi ('unet', 'model1' ou 'model2')

l_noisy = get_batch(num,1,SNR_, 'test')

plot_waveform(l_noisy,masktype,SNR_, SNR_load,output,model,'test')

# %% [markdown]
# # Plot Waveform with unet and binary mask

# %%
from utils.train_and_test import test, display_results, get_batch, plot_waveform
from utils.path import path_n_to_any
import matplotlib.pyplot as plt


SNR_= '-6dB'
SNR_load = '-8dB'
batch_ = 1
lim = 2
masktype='Binary'
output = 'mask'
model = 'unet'
l_noisy = get_batch(lim,batch_,SNR_, 'test')

plot_waveform(l_noisy,masktype,SNR_, SNR_load,output,model,'test')
