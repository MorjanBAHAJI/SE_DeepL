# %%
import os
os.chdir('..')
print(os.getcwd())
from utils.path import path_n_to_any
from utils.train_and_test import test, display_results, get_batch
# Out:
# /home/morjan/Desktop/Project/SE_Deep
# Using TensorFlow backend.

# %% [markdown]
# # Testing denoising with unet and ori

# %%
SNR_= '-6dB' #Choisir son snr (il faut au préalable avoir bruité les sons pour des SNR donné avec gen_noise.py)
SNR_load = '-8dB' #le modèle qu'on souhaite charger (par défaut -8dB car c'est le plus aboutit)
num = 2 #Nombre de sons à écouter
masktype=None # Type de masque ('Soft' ou 'Binary', ou None si on choisi la méthode unet)
output = 'ori' # Type de sortie ("mask" ou "ori")
model = 'unet' # modèle choisi ('unet', 'model1' ou 'model2')

#Ne pas toucher
l_noisy = get_batch(num,1,SNR_, 'test')
names, X_in,X_ori, Y_out = test(l_noisy,masktype,SNR_, SNR_load,output,model,'test')
name_ori = [path_n_to_any(name) for name in names]
display_results(model,name_ori, output, SNR_,X_in, Y_out,masktype=masktype)
# Out:
# 3509.wav noised with an input SNR of:  -6dB ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3509.wav denoised with unet and ori
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3524.wav noised with an input SNR of:  -6dB ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3524.wav denoised with unet and ori
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
# ...

# %% [markdown]
# # Testing denoising with unet and Binary mask

# %%
SNR_= '-6dB' #Choisir son snr (il faut au préalable avoir bruité les sons pour des SNR donné avec gen_noise.py)
SNR_load = '-8dB' #le modèle qu'on souhaite charger (par défaut -8dB car c'est le plus aboutit)
num = 2 #Nombre de sons à écouter
masktype='Binary' # Type de masque ('Soft' ou 'Binary', ou None si on choisi la méthode unet)
output = 'mask' # Type de sortie ("mask" ou "ori")
model = 'unet' # modèle choisi ('unet', 'model1' ou 'model2')

#Ne pas toucher
l_noisy = get_batch(num,1,SNR_, 'test')
names, X_in,X_ori, Y_out = test(l_noisy,masktype,SNR_, SNR_load,output,model,'test')
name_ori = [path_n_to_any(name) for name in names]
display_results(model,name_ori, output, SNR_,X_in, Y_out,masktype=masktype)
# Out:
# 3502.wav noised with an input SNR of:  -6dB ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3502.wav denoised with unet and Binary mask
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3420.wav noised with an input SNR of:  -6dB ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3420.wav denoised with unet and Binary mask
#                 <audio  controls="controls" >
# ...
