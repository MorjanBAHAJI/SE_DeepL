# %% [markdown]
# ## ATTENTION DE N'EXECUTER OS.CHDIR QU'UNE SEULE FOIS, SINON ON SE RETROUVE DANS LE MAUVAIS DOSSIER, RELANCER LE KERNEL SINON

# %%
import os
os.chdir('..')
from utils.train_and_test import get_batch, plot_spectro
from utils.path import path_n_to_any
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## ATTENTION DE N'EXECUTER OS.CHDIR QU'UNE SEULE FOIS, SINON ON SE RETROUVE DANS LE MAUVAIS DOSSIER,  RELANCER LE KERNEL SINON

# %% [markdown]
# # Plot Spectrogram - unet Soft mask

# %%
from utils.train_and_test import plot_spectro

SNR_= '-8dB' #Choisir son snr (il faut au préalable avoir bruité les sons pour des SNR donné avec gen_noise.py)
SNR_load = '-8dB' #le modèle qu'on souhaite charger (par défaut -8dB car c'est le plus aboutit)
num = 1 # nombre de spectro à afficher

masktype='Soft' # Type de masque ('Soft' ou 'Binary', ou None si on choisi la méthode unet)
output = 'mask' # Type de sortie ("mask" ou "ori")
model = 'unet' # modèle choisi ('unet', 'model1' ou 'model2')

mode = 'test' #utiliser l'ensemble de test ou de train

#ne pas toucher
l_noisy = get_batch(lim=num,batch_=1,SNR_=SNR_,mode =mode)
plot_spectro(output,l_noisy,masktype,SNR_,SNR_load,model,mode)
# Out:
# Spectrograms: unet with Soft mask and an input SNR = -8dB

# %% [markdown]
# # Plot Spectrogram - Binary mask

# %%
from utils.train_and_test import plot_spectro

SNR_= '-8dB' #Choisir son snr (il faut au préalable avoir bruité les sons pour des SNR donné avec gen_noise.py)
SNR_load = '-8dB' #le modèle qu'on souhaite charger (par défaut -8dB car c'est le plus aboutit)
num = 1 # nombre de spectro à afficher

masktype=None # Type de masque ('Soft' ou 'Binary', ou None si on choisi la méthode unet)
output = 'ori' # Type de sortie ("mask" ou "ori")
model = 'unet' # modèle choisi ('unet', 'model1' ou 'model2')

mode = 'test' #utiliser l'ensemble de test ou de train

#ne pas toucher
l_noisy = get_batch(lim=num,batch_=1,SNR_=SNR_,mode =mode)
plot_spectro(output,l_noisy,masktype,SNR_,SNR_load,model,mode)
# Out:
# Spectrograms: unet with ori and an input SNR = -8dB

# %% [markdown]
# # Plot Spectrogram - ori
